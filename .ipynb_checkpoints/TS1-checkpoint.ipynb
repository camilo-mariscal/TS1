# %% [markdown]
# ## Teoría de los Circuitos 2
#
# # Trabajo semanal 1
# #### Juan Camilo Mariscal Gutierrez

# %% [markdown]
# ## Consignas
# <img src="./Consigna TS1.png"  />

# %% [markdown]
# ## Resolución
#
# <img src="./1.jpg"  />
#
# <img src="./2.jpg"  />

# %% [markdown]
# ## Simulacion en Python

# %%
 #Librerías externas NumPy, SciPy y Matplotlib
from scipy.signal import TransferFunction
import matplotlib.pyplot as plt
import numpy as np


# Librería de TC2, esta la vas a usar mucho
from pytc2.sistemas_lineales import pzmap, GroupDelay, bodePlot

R1 = 1
R2 = 1

my_tf = TransferFunction( [1,-R1/R2], [1,1] )


plt.close('all')

bodePlot(my_tf)

pzmap(my_tf)
# Out:
# (2, <Axes: xlabel='$\\sigma$', ylabel='j$\\omega$'>)

# %% [markdown]
# ## Simulacion en LTspase
#
# <img src="./TS1.jpg"  />

# %% [markdown]
#  ### 5) se utiliza para modificar la face de las frecuencia
